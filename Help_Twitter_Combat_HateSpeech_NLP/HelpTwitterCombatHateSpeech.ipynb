# %% [markdown]
# <a href="https://colab.research.google.com/github/gmp007/Machine-Learning-and-EDA-Exploratory-Data-Analysis-Projects/blob/main/Help_Twitter_Combat_HateSpeech_NLP/HelpTwitterCombatHateSpeech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install libraries not in default Google Collab
# !pip install contractions

# %% [markdown]
# <p style = "font-size : 25px; color : #ffff ; text-align : center; background-color : #ff9abf; border-radius: 4px 4px;"><strong>Help Twitter Combat Hate Speech on Twitter Platform </strong></p>
#
#
#
#
# <img  style="float: center;  border:5px solid #ffb037;"  src="https://cdn.dribbble.com/users/246068/screenshots/15777269/media/8eaead7fbb2e1dba3e86caa63ac068ec.gif">
#
# This project explores tweets sent by users on the Twitter platform. Being the biggest platform where anybody and everybody can have their views heard, some of these voices spread hate and negativity. Twitter is wary of its platform being used as a medium  to spread hate.
#
#
# ## Objective
# - As a Data Scientist, you're tasked with helping Twitter in identifying the tweets with hate speech and removing them from the platform. You will use NLP techniques, perform specific cleanup for tweets data, and make a robust model.
#
# - Design a machine learning algorithm and handle the imbalance in the dataset.
#
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#ffb037;font-family:newtimeroman;color:##2243b6;font-size:150%;text-align:center;border-radius:8px 10px;">Overview of the project</p>
#
# ## Key steps I have used are:
#
# ### 1) Load Dataset
#
# ### 2) DATA Visualization
#
# ### 3) Data Preprocessing, Cleaning, and Creating
#
# ### 4) Handling Data Imbalnce
#
# ### 5) Model Building and Development with OLR - Training/Testing and Cross-Validation
# <b>DESCRIPTION</b>
#
# Using NLP and ML, make a model to identify hate speech (racist or sexist tweets) in Twitter.
#
# <b>Problem Statement:</b>
# ***
#
# This project explores tweets sent by users on the Twitter platform. Being the biggest platform where anybody and everybody can have their views heard, some of these voices spread hate and negativity. Twitter is wary of its platform being used as a medium  to spread hate.
#
# As a Data Scientist, you're tasked with helping Twitter in identifying the tweets with hate speech and removing them from the platform. You will use NLP techniques, perform specific cleanup for tweets data, and make a robust model.
#
# Domain: Social Media
#
# <b>Analysis to be done:</b> Clean up tweets and build a classification model by using NLP techniques, cleanup specific for tweets data, regularization and hyperparameter tuning using stratified k-fold and cross validation to get the best model.
#
# <b>Content: </b>
#
# id: identifier number of the tweet
#
# Label: 0 (non-hate) /1 (hate)
#
# Tweet: the text in the tweet
# ***
#
# <b>Tasks: </b>
#
# Load the dataset.
#
# <b>Cleanup Dataset: </b>
#
# - Normalize the casing.
# - Using regular expressions, remove user handles. These begin with '@'.
# - Using regular expressions, remove URLs.
# - Using TweetTokenizer from NLTK, tokenize the tweets into individual terms.
# - Remove stop words.
# - Remove redundant terms like ‘amp', ‘rt', etc.
# - Remove ‘#' symbols from the tweet while retaining the term.
# - Extra cleanup by removing terms with a length of 1.
# - Apply other methods to further clean up the dataset
#
#
# <b>Data formatting for predictive modeling:</b>
# - Join the tokens back to form strings. This will be required for the vectorizers.
# - Assign x and y.
# - Perform train_test_split using sklearn.
#
# <b>Use TF-IDF values for the terms as a feature to get into a vector space model.</b>
# - Import TF-IDF  vectorizer from sklearn.
# - Instantiate with a maximum of 5000 terms in your vocabulary.
# - Fit and apply on the train set.
# - Apply on the test set.
#
# </b>Model building: Ordinary Logistic Regression</b>
# - Instantiate Logistic Regression from sklearn with default parameters.
# - Fit into  the train data.
# - Make predictions for the train and the test set.
#
# <b>Model evaluation: Accuracy, recall, and f_1 score.</b>
# - Report the accuracy on the train set.
# - Report the recall on the train set: decent, high, or low.
# - Get the f1 score on the train set.
#
# <b>Looks like you need to adjust the class imbalance, as the model seems to focus on the 0s.</b>
# - Adjust the appropriate class in the LogisticRegression model.
#
# <b>Train again with the adjustment and evaluate.</b>
# - Train the model on the train set.
# - Evaluate the predictions on the train set: accuracy, recall, and f_1 score.
#
# <b>Regularization and Hyperparameter tuning:</b>
# - Import GridSearch and StratifiedKFold.
# - Provide the parameter grid to choose for ‘C' and ‘penalty' parameters.
# - Use a balanced class weight while instantiating the logistic regression.
#
# <b>Determine the parameters with the best recall in the cross-validation.</b>
# - Choose ‘recall' as the metric for scoring.
# - Choose a stratified 5 fold cross-validation scheme.
# - Apply the model by fitting the train dataset.
#
# <b>What are the best parameters?</b>
#
# <b>Predict and evaluate using the best estimator.</b>
# - Use the best estimator from the grid search to make predictions on the test set.
# - What is the recall on the test set for the hate comments?
# - What is the f_1 score?
#
# <b>Beyond OLS.</b>
# - Explore other ML methods to determine the best model based on combined metrics
# - To handle the imbalance, use Smote
# - Using the best ML model, use gridsearch to determine the hyperparameters
# - Use the optimized parameters, determine the metrics, e.g., f_1 score

# %% [markdown]
# ## Table of Contents
#
# - [1 - Import Libraries and Load Data](#1)
# - [2 - Text Cleaning](#2)
#     - [2.1 - Handle Diacritics using Text Normalization](#2-1)
#     - [2.1 - Remove user handles](#2-2)
#     - [2.2 - Remove the URLs](#2-3)
#     - [2.3 - Tokenize using TweetTokenizer](#2-4)
#     - [2.4 - Remove Stopwords](#2-5)
#     - [2.5 - Spelling Corrections](#2-6)
#     - [2.6 - Remove #symbols while retaining the text](#2-7)
#     - [2.7 - Remove single and double character length tokens ](#2-8)
#     - [2.8 - Remove digits](#2-9)
#     - [2.9 - Remove non alpha numeric characters ](#2-10)
#
#
# - [3 - Exploratory Data Analysis](#3)
#     - [3.1 - Check for data imbalance](#3-1)
#     - [3.2 - Check top terms in the tweet](#3-2)
#
# - [ 4 - Predictive Modeling](#4)
#     - [4.1 - Data Formatting for Predidictive Modeling](#4-1)
#     - [4.2 - Using tf-idf vectorizer to generate the feature vectors](#4-2)
#     - [4-3 - Model using Ordinary Logistic Regression with Default Parameters](#4-3)
#     - [4-4 - Model Evaluation](#4-4)
#     - [4-5 - Model using Weighted Logistic Regression to handle data imbalance](#4-5)
#     - [4-6 - Model Fine Tuning using Randomized Grid Search](#4-6)
#     - [4-7 - Fine Tuned Model Prediction & Evaluation with balanced class weights](#4-7)
#     - [4-8 - Fine Tuned Model Prediction & Evaluation with imbalanced class weights](#4-8)
# - [5 - Summary OLS](#5)
#
# - [6 - Beyond OLS](#6)
#     - [6.1 - Handle Imbalance with Smote](#6-1)
#     - [6.2 - Search for the best ML Model Exploring Metrics](#6-2)
#     - [6.3 - Perform Hyperparameter Training of Best ML Model](#6-3)
#     - [6.4 - Summary of beyond OLS Model Developing and Training](#6-4)

# %% [markdown]
# <a id='1'></a>
# ## _Import Libraries and Load Data_

# %%
#General packages for data manipulation
import os
import time
import math
import pandas as pd
import numpy as np
from numpy import std
from termcolor import cprint
#visualizations
import matplotlib.pyplot as plt
import seaborn as sns
import string
from textblob import TextBlob
from collections import Counter
import itertools
import collections
from itertools import cycle
from scipy.stats import loguniform

# %matplotlib inline 
from pylab import rcParams
rcParams['figure.figsize']=12,5
rcParams['axes.labelsize']=12
rcParams['xtick.labelsize']=12
rcParams['ytick.labelsize']=12


# Text Preprocessing & Cleaning
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
import re
import contractions
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import WordPunctTokenizer
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import sent_tokenize
from nltk.tokenize import WordPunctTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import re
#display pandas dataframe columns 
pd.options.display.max_columns = None

#ML model building and training
from sklearn.model_selection import train_test_split # Split Data 
from imblearn.over_sampling import SMOTE # Handling Imbalanced  
#import the required libraries for grid search
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold

#import the metrics
from sklearn.metrics import classification_report , accuracy_score,f1_score,auc # Performance Metrics 
from sklearn.metrics import precision_score, recall_score,roc_curve,roc_auc_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import average_precision_score

# Model Building
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression,LogisticRegressionCV,RidgeClassifierCV,RidgeClassifier, Perceptron
from sklearn.ensemble import RandomForestClassifier 
from sklearn.tree import DecisionTreeClassifier,ExtraTreeClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import MultinomialNB,BernoulliNB,GaussianNB
from sklearn.linear_model import SGDClassifier
from xgboost import XGBClassifier
from sklearn import svm
#from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer 
from sklearn.ensemble import AdaBoostClassifier,ExtraTreesClassifier 

from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import label_binarize

from sklearn.model_selection import ShuffleSplit, cross_validate

import warnings

random_seed = 101
test_size = 0.20
hyperparameter =False
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
timetotal = time.time() #Use this to compute the total time for the case study

# %% [markdown]
# ## Load the Dataset

# %%
#ISO-8859-1
df = pd.read_csv('TwitterHate.csv',delimiter=',',engine='python',encoding='utf-8-sig')
df.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
#Remove the identifier (id label) of the tweet
df.drop('id',axis=1,inplace=True)

# %%
#Randomly view a tweet
random = np.random.randint(0,len(df))
print(random)
df.iloc[random]['tweet']
# Out:
# 30370
# "be   n #healthy you don't walk into love, you fall in. that's why it's so hard to get out. â\x80\x93 unknown "

# %%
#Just in case, let's keep a copy of the original dataset. 
df_copy = df.copy()

# %% [markdown]
# <a id="1"></a>
# # <p style="background-color:#ffb037;font-family:newtimeroman;color:#2243b6;font-size:100%;text-align:center;border-radius:8px 10px;">EXPLORATORY DATA ANALYSIS</p>

# %%
# Check for null values
cprint('Total Null Values in dataset :','green')
print(df.isnull().sum()) # showing null values of train data
plt.figure(figsize=(14,8))


# visualize null values
sns.heatmap(df.isnull(), yticklabels = False, cmap='magma')
plt.title('Total null values of dataset',size=20);
# Out:
# Total Null Values in dataset :
# label    0
# tweet    0
# dtype: int64

# %%
# Percentage
test = df
test = test.rename(columns={'label':'Percentage distribution of Total Tweets Per Type'})
percentage = pd.DataFrame(round(test['Percentage distribution of Total Tweets Per Type'].value_counts().sort_values(ascending=False) / len(df) * 100, 2))
display(percentage)
# Out:
#    Percentage distribution of Total Tweets Per Type
# 0                                             92.99
# 1                                              7.01

# %%
# View the sentiments
colors = ("green", "orange", "cyan")
labels = "Non-hate speech", "Hate speech"
pd.Series(df['label']).value_counts().plot(kind='pie',
                                                       colors=colors,labels=labels,
                                                       shadow=True,autopct='%.2f',
                                                       fontsize=12,figsize=(6,6),
                                                       title="Total Tweets for Each Sentiment")

plt.show()

# %%
# Replotting
sns.countplot(x = "label", data = df)

# %% [markdown]
# <a id="1"></a>
# # <p style="background-color:#ffb037;font-family:newtimeroman;color:#2243b6;font-size:100%;text-align:center;border-radius:8px 10px;">DATA PREPROCESSING AND CLEANING</p>

# %%
#Check that it works as expected
sample = "[Given that @user1 is in Dubai, better to zoom with @user2 and @username3]"
pattern = re.compile(r'@\w+')
re.findall(pattern,sample)

def remove_username(text): #Alternatively, use this
    return re.sub('@[^\s]+','',text)
remove_username(sample)
# Out:
# '[Given that  is in Dubai, better to zoom with  and '

# %%
# Let's use this latest and more efficient form
def remove_username(text): #Alternatively, use this
    tknzr = TweetTokenizer(strip_handles=True)
    return tknzr.tokenize(text) #re.sub('@[^\s]+','',text)
remove_username(sample)
# Out:
# ['[',
#  'Given',
#  'that',
#  'is',
#  'in',
#  'Dubai',
#  ',',
#  'better',
#  'to',
#  'zoom',
#  'with',
#  'and',
#  ']']

# %% [markdown]
# <a id='2-2'></a>
# #### (b) _Remove user handles_

# %%
#Remove all the user handles
#df['tweet'].replace(r'@\w+','',regex=True,inplace=True)
df['tweet'] =  df['tweet'].apply(lambda x : remove_username(x))
df['tweet']
# Out:
# 0        [when, a, father, is, dysfunctional, and, is, ...
# 1        [thanks, for, #lyft, credit, i, can't, use, ca...
# 2                                  [bihday, your, majesty]
# 3        [#model, i, love, u, take, with, u, all, the, ...
# 4               [factsguide, :, society, now, #motivation]
#                                ...
# 31957    [ate, isz, that, youuu, ?, ð, , , , ð, , ...
# 31958    [to, see, nina, turner, on, the, airwaves, try...
# 31959    [listening, to, sad, songs, on, a, monday, mor...
# 31960    [#sikh, #temple, vandalised, in, in, #calgary,...
# 31961                       [thank, you, for, you, follow]
# Name: tweet, Length: 31962, dtype: object

# %% [markdown]
# <a name='2-1'></a>
# #### (a) _Handle Diacritics using text normalization_

# %%
def simplify(text):
    '''Function to handle the diacritics in the text'''
    import unicodedata
    try:
        text = unicode(text, 'utf-8')
    except NameError:
        pass
    text = unicodedata.normalize('NFD', text).encode('ascii', 'ignore').decode("utf-8")
    return str(text)

# %%
df['tweet'] = [' '.join(map(str, l)) for l in df['tweet']]
df['tweet'] = df['tweet'].apply(simplify)

# %%
df.head()
# Out:
#    label                                              tweet
# 0      0  when a father is dysfunctional and is so selfi...
# 1      0  thanks for #lyft credit i can't use cause they...
# 2      0                                bihday your majesty
# 3      0  #model i love u take with u all the time in ur...
# 4      0               factsguide : society now #motivation

# %% [markdown]
# <a id='2-3'></a>
# #### (c) _Remove the urls_

# %%
# Remove any url
def remove_url(text):
    """Replace URLs found in a text string with nothing 
    (i.e. it will remove the URL from the string).

    Parameters
    ----------
    txt : string
        A text string that you want to parse and remove urls.

    Returns
    -------
    The same txt string with url's removed.
    """

    return " ".join(re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", text).split())

# %%
df['tweet'] = df['tweet'].apply(remove_url)

# %%
#test on a sample 
sampletext = "https://www.machinelearing.com Graphene and https://www.ekuma.com"
urlleft = re.compile(r'http\S+')
re.findall(urlleft,sampletext)
# Out:
# ['https://www.machinelearing.com', 'https://www.ekuma.com']

# %%
# Alternatively, we can use:
def remove_url(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'',text)

# %%
#df['tweet'].replace(r'http\S+','',regex=True,inplace=True)

# %% [markdown]
# <a id='2-3'></a>
# #### (d) _Expand contracted words_

# %%
#Define dictionary of words to expand
dictionary_contracts= { "ain't": "are not", "'s":" is", "aren't": "are not", 
                       "can't": "cannot", "can't've": "cannot have", "‘cause": 
                       "because", "could've": "could have", "couldn't": "could not", 
                       "couldn't've": "could not have", "didn't": "did not", 
                       "doesn't": "does not", "don't": "do not", "hadn't": "had not", 
                       "hadn't've": "had not have", "hasn't": "has not", "haven't": "have not", 
                       "he'd": "he would", "he'd've": "he would have", "he'll": "he will", 
                       "he'll've": "he will have", "how'd": "how did", "how'd'y": "how do you", 
                       "how'll": "how will", "I'd": "I would", "I'd've": "I would have", 
                       "I'll": "I will", "I'll've": "I will have", "I'm": "I am", "I've": "I have", 
                       "isn't": "is not", "it'd": "it would", "it'd've": "it would have", 
                       "it'll": "it will", "it'll've": "it will have", "let's": "let us", 
                       "ma'am": "madam", "mayn't": "may not", "might've": "might have", 
                       "mightn't": "might not", "mightn't've": "might not have", "must've": "must have", 
                       "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", 
                       "needn't've": "need not have", "o'clock": "of the clock", "oughtn't": "ought not", 
                       "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", 
                       "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", 
                       "she'll": "she will", "she'll've": "she will have", "should've": "should have", 
                       "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have", 
                       "that'd": "that would", "that'd've": "that would have", "there'd": "there would", 
                       "there'd've": "there would have", "they'd": "they would", 
                       "they'd've": "they would have","they'll": "they will", 
                       "they'll've": "they will have", "they're": "they are", "they've": "they have", 
                       "to've": "to have", "wasn't": "was not", "we'd": "we would", 
                       "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", 
                       "we're": "we are", "we've": "we have", "weren't": "were not","what'll": "what will", 
                       "what'll've": "what will have", "what're": "what are", "what've": "what have", 
                       "when've": "when have", "where'd": "where did", "where've": "where have", 
                       "who'll": "who will", "who'll've": "who will have", "who've": "who have", 
                       "why've": "why have", "will've": "will have", "won't": "will not", 
                       "won't've": "will not have", "would've": "would have", "wouldn't": "would not", 
                       "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would", 
                       "y'all'd've": "you all would have", "y'all're": "you all are", 
                       "y'all've": "you all have", "you'd": "you would", "you'd've": "you would have", 
                       "you'll": "you will", "you'll've": "you will have", "you're": "you are", 
                       "you've": "you have",'gr8':'great',"i'm": "i am"}

# %%
expand_re = re.compile('(%s)'%'|'.join(dictionary_contracts.keys()))

# %%
df.head()
# Out:
#    label                                              tweet
# 0      0  when a father is dysfunctional and is so selfi...
# 1      0  thanks for lyft credit i cant use cause they d...
# 2      0                                bihday your majesty
# 3      0      model i love u take with u all the time in ur
# 4      0                  factsguide society now motivation

# %%
def expand_contractions(s, contractions_dict=dictionary_contracts):
  def replace(match):
    return dictionary_contracts[match.group(0)]
  return expand_re.sub(replace, s)

# %%
df['tweet'] = df['tweet'].apply(expand_contractions)

# %%
df.head(10)
# Out:
#    label                                              tweet
# 0      0  when a father is dysfunctional and is so selfi...
# 1      0  thanks for lyft credit i cant use cause they d...
# 2      0                                bihday your majesty
# 3      0      model i love u take with u all the time in ur
# 4      0                  factsguide society now motivation
# 5      0  22 huge fan fare and big talking before they l...
# 6      0                            camping tomorrow dannya
# 7      0  the next school year is the year for exams can...
# 8      0  we won love the land allin cavs champions clev...
# 9      0                       welcome here im its so great

# %% [markdown]
# <a id='2-4'></a>
# #### (e) _Text Tokenization using tweet tokenizer_

# %%
#Let's check how it works first
sampletest = 'great! :-)  will you attend the #birthday bash today'
tweet_tokenize = TweetTokenizer(preserve_case=False,strip_handles=True,reduce_len=True)
tweet_tokenize.tokenize(sampletest)
# Out:
# ['great',
#  '!',
#  ':-)',
#  'will',
#  'you',
#  'attend',
#  'the',
#  '#birthday',
#  'bash',
#  'today']

# %%
# Tokenize
tweet_tokens = []
tweet_tokenizer = TweetTokenizer(preserve_case=False,strip_handles=True,reduce_len=True)
for sent in df['tweet']:
#    print(tweet_tokenizer.tokenize(sent))
    tweet_tokens.append(tweet_tokenizer.tokenize(sent))
    
tokenizers = {'TweetTokenizer': tweet_tokens}

df['tweet'] = pd.DataFrame.from_dict(tokenizers)

#Alternatively, use:
#tokenizer = TweetTokenizer(preserve_case=False,strip_handles=True,reduce_len=True)
#df['tweet'] = df['tweet'].apply(tokenizer.tokenize)

# %%
df['tweet']
# Out:
# 0        [when, a, father, is, dysfunctional, and, is, ...
# 1        [thanks, for, lyft, credit, i, cant, use, caus...
# 2                                  [bihday, your, majesty]
# 3        [model, i, love, u, take, with, u, all, the, t...
# 4                   [factsguide, society, now, motivation]
#                                ...
# 31957                        [ate, isz, that, youuu, a, i]
# 31958    [to, see, nina, turner, on, the, airwaves, try...
# 31959    [listening, to, sad, songs, on, a, monday, mor...
# 31960    [sikh, temple, vandalised, in, in, calgary, ws...
# 31961                       [thank, you, for, you, follow]
# Name: tweet, Length: 31962, dtype: object

# %% [markdown]
# <a id='2-5'></a>
# #### (e) _Remove the Stopwords in the tweets_

# %%
stop_words = stopwords.words('english')

#add additional stop words to be removed from the text
additional_list = ['pam', 'gy' 'amp','rt','u',"can't",'ur']

for words in additional_list:
    stop_words.append(words)

# %%
stop_words[-13:]
# Out:
# ["wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'pam',
#  'gyamp',
#  'rt',
#  'u',
#  "can't",
#  'ur']

# %%
#remove stop words
def remove_stopwords(text):
    '''Function to remove the stop words from the text corpus'''
    text = [word for word in text if not word in stop_words]
    return text  

#Remove the stop words from the tweets
df['tweet'] = df['tweet'].apply(remove_stopwords)

# %%
df['tweet'].head(10)
# Out:
# 0    [father, dysfunctional, selfish, drags, kids, ...
# 1    [thanks, lyft, credit, cant, use, cause, dont,...
# 2                                    [bihday, majesty]
# 3                            [model, love, take, time]
# 4                    [factsguide, society, motivation]
# 5    [22, huge, fan, fare, big, talking, leave, cha...
# 6                          [camping, tomorrow, dannya]
# 7    [next, school, year, year, exams, cant, think,...
# 8    [love, land, allin, cavs, champions, cleveland...
# 9                                 [welcome, im, great]
# Name: tweet, dtype: object

# %% [markdown]
# <a id='2-7'></a>
# #### (f) _Remove the hastag symbol while retaining the text_

# %%
#Check that works as expected before using it
sample = '#Word cup #2024'
pattern = re.compile(r'#')
re.sub(pattern,'',sample)
# Out:
# 'Word cup 2024'

# %%
def remove_hashsymbols(text):
    '''Function to remove the hashtag symbol # from a text'''
    pattern = re.compile(r'#')
    text = ' '.join(text)
    cleaned_text = re.sub(pattern,'',text)
    return tweet_tokenizer.tokenize(cleaned_text)

# %%
# Apply the function to the tweets
df['tweet'] = df['tweet'].apply(remove_hashsymbols)

# %%
# Remove emoji in tweets. I checked none
#df['tweet'] = df['tweet'].str.replace('[^\w\s#@/:%.,_-]', '', flags=re.UNICODE)

# %%
df.head(10)
# Out:
#    label                                              tweet
# 0      0  [father, dysfunctional, selfish, drags, kids, ...
# 1      0  [thanks, lyft, credit, cant, use, cause, dont,...
# 2      0                                  [bihday, majesty]
# 3      0                          [model, love, take, time]
# 4      0                  [factsguide, society, motivation]
# 5      0  [22, huge, fan, fare, big, talking, leave, cha...
# 6      0                        [camping, tomorrow, dannya]
# 7      0  [next, school, year, year, exams, cant, think,...
# 8      0  [love, land, allin, cavs, champions, cleveland...
# 9      0                               [welcome, im, great]

# %% [markdown]
# <a id='2-10'></a>
# #### (g) _Remove special characters_

# %%
def remove_nonalpha(text):
    '''Function to remove the non-alphanumeric characters from the text'''
    text = [word for word in text if word.isalpha()]
    return text
#remove the non alpha numeric characters from the tweet tokens
df['tweet'] = df['tweet'].apply(remove_nonalpha)
df.head(10)
# Out:
#    label                                              tweet
# 0      0  [father, dysfunctional, selfish, drags, kids, ...
# 1      0  [thanks, lyft, credit, cant, use, cause, dont,...
# 2      0                                  [bihday, majesty]
# 3      0                          [model, love, take, time]
# 4      0                  [factsguide, society, motivation]
# 5      0  [huge, fan, fare, big, talking, leave, chaos, ...
# 6      0                        [camping, tomorrow, dannya]
# 7      0  [next, school, year, year, exams, cant, think,...
# 8      0  [love, land, allin, cavs, champions, cleveland...
# 9      0                               [welcome, im, great]

# %% [markdown]
# <a id='2-8'></a>
# #### (h) _Remove numbers, punctuation, etc from the tweets_

# %%
# Decontraction tweet
def tokenizetweet(tweet):
    # remove numbers
    tweet_nonum = re.sub(r'\d+', '', tweet)
    # remove punctuations and convert characters to lower case
    tweet_nopunct = "".join([char.lower() for char in tweet_nonum if char not in string.punctuation]) 
    # substitute multiple whitespace with single whitespace
    # Also, removes leading and trailing whitespaces
    tweet_no_dspace = re.sub('\s+', ' ', tweet_nopunct).strip()
    return tweet_no_dspace

# %%
df['tweet'] = [' '.join(map(str, l)) for l in df['tweet']]
df['tweet'] = df['tweet'].apply(lambda x : tokenizetweet(x))
#df['tweet'] = df['tweet'].apply(tokenizetweet)
df.head(10)
# Out:
#    label                                              tweet
# 0      0  father dysfunctional selfish drags kids dysfun...
# 1      0  thanks lyft credit cant use cause dont offer w...
# 2      0                                     bihday majesty
# 3      0                               model love take time
# 4      0                      factsguide society motivation
# 5      0  huge fan fare big talking leave chaos pay disp...
# 6      0                            camping tomorrow dannya
# 7      0  next school year year exams cant think school ...
# 8      0  love land allin cavs champions cleveland cleve...
# 9      0                                   welcome im great

# %% [markdown]
# <a id='2-6'></a>
# #### (i) _Check and correct spellings_

# %%
#from autocorrect import Speller #Works like textblob
#spell = Speller(lang='en')
#sampletext = 'amazng how the man treated the lyft driveer'
#spell(sampletext)

# %%
#Test that it works as expected.
sampletext = 'amazng how the man treated the lyft driveer'
txtblob = TextBlob(sampletext)
corrected_text = txtblob.correct()
print(corrected_text)
# Out:
# amazing how the man treated the left driver

# %%
#textblob expect a string to be passed and not a list of strings
from textblob import TextBlob

def spell_check(text):
    '''Function to do spelling correction using '''
    txtblob = TextBlob(text)
    corrected_text = txtblob.correct()
    return corrected_text

# %%
# This takes a lot of time. Consider commenting out.
#df['tweet'] = df['tweet'].apply(spell_check)
df.head(10)
# Out:
#    label                                              tweet
# 0      0  father dysfunctional selfish drags kids dysfun...
# 1      0  thanks lyft credit cant use cause dont offer w...
# 2      0                                     bihday majesty
# 3      0                               model love take time
# 4      0                      factsguide society motivation
# 5      0  huge fan fare big talking leave chaos pay disp...
# 6      0                            camping tomorrow dannya
# 7      0  next school year year exams cant think school ...
# 8      0  love land allin cavs champions cleveland cleve...
# 9      0                                   welcome im great

# %% [markdown]
# <a id='3'></a>
# ### _Further Exploratory Data Analysis_

# %% [markdown]
# <a id='3-1'></a>
# #### _Recheck for data balance distribution_

# %%
#plot of the count of hate and non hate tweet
sns.countplot(x = "label", data = df)
plt.title('No of Hate vs Non-hate Tweets')
plt.grid()
plt.show()

# %% [markdown]
# _There are more non hate speeches than hate speeches in the dataset_

# %% [markdown]
# <a id='3-2'></a>
# ### _Explore the top terms in the tweets_

# %%
words_in_tweet = [tweet.lower().split() for tweet in df['tweet'] ]
words_in_tweet[:2]
# Out:
# [['father', 'dysfunctional', 'selfish', 'drags', 'kids', 'dysfunction', 'run'],
#  ['thanks',
#   'lyft',
#   'credit',
#   'cant',
#   'use',
#   'cause',
#   'dont',
#   'offer',
#   'wheelchair',
#   'vans',
#   'pdx',
#   'disapointed',
#   'getthanked']]

# %%
# List of all words across tweets
all_words_in_tweet = list(itertools.chain(*words_in_tweet))

# Create counter
counts_tweet_words = collections.Counter(all_words_in_tweet)

counts_tweet_words.most_common(20)
# Out:
# [('love', 2761),
#  ('day', 2312),
#  ('happy', 1698),
#  ('im', 1154),
#  ('time', 1138),
#  ('life', 1123),
#  ('like', 1110),
#  ('today', 1018),
#  ('new', 994),
#  ('thankful', 947),
#  ('positive', 931),
#  ('get', 919),
#  ('good', 863),
#  ('people', 859),
#  ('bihday', 855),
#  ('cant', 816),
#  ('one', 784),
#  ('see', 762),
#  ('dont', 724),
#  ('fathers', 715)]

# %%
df_counts_tweet_words = pd.DataFrame(counts_tweet_words.most_common(15),
                             columns=['Words', 'Count'])

df_counts_tweet_words.head()
# Out:
#    Words  Count
# 0   love   2761
# 1    day   2312
# 2  happy   1698
# 3     im   1154
# 4   time   1138

# %%
fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
df_counts_tweet_words.sort_values(by='Count').plot.barh(x='Words',
                      y='Count',
                      ax=ax,
                      color="green")

ax.set_title("Common Words Found in Tweets (Including All Words)")

plt.show()

# %%
#Visualize the 20 top most common tweets by plotting the cumulative frequency 
frequency = nltk.FreqDist(counts_tweet_words)
plt.title('Top 20 Most Common Terms in Tweets')
frequency.plot(20,cumulative=True)
plt.show()

# %%
#plot the frequency of the top 10 most common tokens 
frequency = nltk.FreqDist(counts_tweet_words)
plt.title('Top 20 Most Common Terms')
frequency.plot(20,cumulative=False)
plt.show()

# %% [markdown]
# _Love is the most frequently used word followed by day, happy etc. This is expected as there are more non hate tweets than hate tweets in the dataset_

# %% [markdown]
# <a id='4'></a>
# ## _Predictive Modeling_

# %% [markdown]
# ### _Data Formatting for Predictive Modeling_

# %%
df.head()
# Out:
#    label                                              tweet
# 0      0  father dysfunctional selfish drags kids dysfun...
# 1      0  thanks lyft credit cant use cause dont offer w...
# 2      0                                     bihday majesty
# 3      0                               model love take time
# 4      0                      factsguide society motivation

# %%
#Check for null values again
df.isnull().sum()
# Out:
# label    0
# tweet    0
# dtype: int64

# %%
#Join the tokens back to form the string # Already done above
#df['tweet'] = df['tweet'].apply(lambda x: ' '.join(x))

# %%
#check the top rows
df.head(10)
# Out:
#    label                                              tweet
# 0      0  father dysfunctional selfish drags kids dysfun...
# 1      0  thanks lyft credit cant use cause dont offer w...
# 2      0                                     bihday majesty
# 3      0                               model love take time
# 4      0                      factsguide society motivation
# 5      0  huge fan fare big talking leave chaos pay disp...
# 6      0                            camping tomorrow dannya
# 7      0  next school year year exams cant think school ...
# 8      0  love land allin cavs champions cleveland cleve...
# 9      0                                   welcome im great

# %%
#split the data into input X and output y
X = df['tweet']
y = df['label']

# %%
#split the data 
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=test_size,random_state=random_seed,stratify=df['label'])

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (25569,) (6393,) (25569,) (6393,)

# %% [markdown]
# <a id='4-2'></a>
# ### _Use tf-idf as a feature to get into the vector space model_

# %%
#instantiate the vectorizer 
vectorizer = TfidfVectorizer(max_features=5000)

# %%
#fit on the training data
X_train = vectorizer.fit_transform(X_train)
#transform the test data
X_test = vectorizer.transform(X_test)

# %%
#check the shape
X_train.shape, X_test.shape
# Out:
# ((25569, 5000), (6393, 5000))

# %%
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True) 
tfidf_transformer.fit(X_train)

# print idf values 
df_idf = pd.DataFrame(tfidf_transformer.idf_, index=vectorizer.get_feature_names_out(),columns=["idf_weights"]) 
 
# sort ascending 
df_idf.sort_values(by=['idf_weights'])
# Out:
#            idf_weights
# love          3.528960
# day           3.700259
# happy         3.987553
# im            4.356831
# time          4.388760
# ...                ...
# maui         10.050563
# coachella    10.050563
# freemilo     10.456028
# deceive      10.456028
# quack        10.456028
#
# [5000 rows x 1 columns]

# %%
# Compute the TFIDF score for the dataset
feature_names = vectorizer.get_feature_names_out() 

# count matrix 
count_vector=vectorizer.transform(X) 

# tf-idf scores 
tf_idf_vector=tfidf_transformer.transform(count_vector)

#get tfidf vector for 2nd document 
first_document_vector=tf_idf_vector[1] 
 
#print the scores 
df_tdf = pd.DataFrame(first_document_vector.T.todense(), index=feature_names, columns=["tfidf"]) 
df_tdf.sort_values(by=["tfidf"],ascending=False)
# Out:
#              tfidf
# credit    0.579803
# offer     0.501516
# cause     0.413906
# use       0.343801
# thanks    0.248908
# ...            ...
# friday    0.000000
# fri       0.000000
# freshsta  0.000000
# fresh     0.000000
# zoro      0.000000
#
# [5000 rows x 1 columns]

# %% [markdown]
# <a id='4-3'></a>
# ### _Model building: Ordinary Logistic Regression_

# %%
#instantiate the models with default hyper-parameters
timet = time.time() # Calculate time
clf = LogisticRegression()
clf.fit(X_train,y_train)
train_predictions = clf.predict(X_train)
test_predictions = clf.predict(X_test)
print(f'Time for the OLS model is: {time.time()-timet}')
# Out:
# Time for the OLS model is: 0.8093955516815186

# %% [markdown]
# <a id='4-4'></a>
# ### _Model evaluation_

# %%
#get the model accuracy on the training and the test set
print('Accuracy Score of the training dataset %.5f' %accuracy_score(y_train,train_predictions))
print('Accuracy Score of test dataset %.5f' %accuracy_score(y_test,test_predictions))
# Out:
# Accuracy Score of the training dataset 0.95514
# Accuracy Score of test dataset 0.95104

# %% [markdown]
# _The accuracy score as in the R^2 value is never a good metric for an imbalanced dataset as in this case. This can be highighted using the f1 score. A low f1-score for a label indicate poor performance of the model._

# %%
print('Classification Report for the Training dataset')
print('\n')
print(classification_report(y_train,train_predictions))
# Out:
# Classification Report for the Training dataset
#
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     23775
#            1       0.94      0.38      0.55      1794
#
#     accuracy                           0.96     25569
#    macro avg       0.95      0.69      0.76     25569
# weighted avg       0.95      0.96      0.95     25569

# %%
print('Classification Report for the Testing dataset')
print('\n')
print(classification_report(y_test,test_predictions))
# Out:
# Classification Report for the Testing dataset
#
#
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      5945
#            1       0.92      0.33      0.49       448
#
#     accuracy                           0.95      6393
#    macro avg       0.94      0.66      0.73      6393
# weighted avg       0.95      0.95      0.94      6393

# %% [markdown]
# _As anticipated the model's f1-score is low for label 1 => the hate speech, which is the minority in this case._

# %% [markdown]
# <a id='4-5'></a>
# ### _Weighted Logistic Regression Or Cost Sensitive Logistic Regression_

# %%
df.head()
# Out:
#    label                                              tweet
# 0      0  father dysfunctional selfish drags kids dysfun...
# 1      0  thanks lyft credit cant use cause dont offer w...
# 2      0                                     bihday majesty
# 3      0                               model love take time
# 4      0                      factsguide society motivation

# %%
df['label'].value_counts()
# Out:
# 0    29720
# 1     2242
# Name: label, dtype: int64

# %%
hatespeech = len(df[df['label'] == 1])
nonhatespeech = len(df[df['label'] == 0])
print(hatespeech,nonhatespeech)
div = math.gcd(nonhatespeech,hatespeech)
print(f'The hate speech is {hatespeech} and nonhate speech is {nonhatespeech}')
print(f'The ratio corresponds to {nonhatespeech/div}:{hatespeech/div}')
print(f'This is approximately 13:1')
# Out:
# 2242 29720
# The hate speech is 2242 and nonhate speech is 29720
# The ratio corresponds to 14860.0:1121.0
# This is approximately 13:1

# %%
#define the weight of the class labels using inverse ratio
timet = time.time() # Calculate time
weights = {0:1.0,1:13.0}

#instantiate the logistic regression model and account for the weights to be applied for model coefficients update magnitude
clf = LogisticRegression(solver='lbfgs',class_weight=weights,max_iter=1000)

#fit and predict
clf.fit(X_train,y_train)
train_predictions = clf.predict(X_train)
test_predictions = clf.predict(X_test)

print(f'Time for the model training for balance data is: {time.time()-timet}')

#classification report
print('Classification Report Training set')
print('------------------------------------')
print('\n')
print(classification_report(y_train,train_predictions))
print('\n')

print('Classification Report Testing set')
print('------------------------------------')
print('\n')
print(classification_report(y_test,test_predictions))
# Out:
# Time for the model training for balance data is: 1.2485525608062744
# Classification Report Training set
# ------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97     23775
#            1       0.61      0.98      0.75      1794
#
#     accuracy                           0.95     25569
#    macro avg       0.80      0.97      0.86     25569
# weighted avg       0.97      0.95      0.96     25569
#
#
#
# Classification Report Testing set
# ------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96      5945
#            1       0.50      0.77      0.61       448
#
#     accuracy                           0.93      6393
#    macro avg       0.74      0.86      0.78      6393
# weighted avg       0.95      0.93      0.94      6393

# %% [markdown]
# _The f1 score of both the training and testing set has improved compared to the plain vanilla Logistic Regression model. There is still more opportunity to improve the score using better models or even handling the data imbalance by adding synthetic data_

# %% [markdown]
# <a id='4-6'></a>
# ### _Regularization and Hyperparameter tuning:_

# %%
# define search space for the hyper parameters
space = dict()
space['solver'] = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
space['penalty'] = ['l2']
space['C'] = loguniform(1e-5, 100)

# %%
#check the search space 
print(space)
# Out:
# {'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'], 'penalty': ['l2'], 'C': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f36a04bef90>}

# %% [markdown]
# <a id='4-7'></a>
# ### _Hyper parameter modeling with Balanced Class Weights_

# %%
#define the model with balanced class weights

weights = {0:1.0,1:1.0}
if(hyperparameter == True):
    timet = time.time() # Calculate time
    clf = LogisticRegression(class_weight=weights,max_iter =1000)
    #define the number of folds 
    folds = StratifiedKFold(n_splits=5,random_state=random_seed,shuffle=True)
    # define search
    grid_search = RandomizedSearchCV(estimator=clf,param_distributions=space, n_iter=1000, scoring='recall',
                                n_jobs=-1, cv=folds, random_state=random_seed)
    #fit grid search on the train data
    grid_result = grid_search.fit(X_train,y_train)

    print(f'Time for the hyperparameter training for unbalance class weight is: {time.time()-timet}')

# %%
#Determine the best model 
#grid_result.best_estimator_

# %%
#Instantiate the ML with the best model
#clf = LogisticRegression(C=88.22063349588299,penalty='l2',solver='saga',max_iter=500,class_weight=weights)

# %%
#Instantiate the ML with the best model
clf = LogisticRegression(C=97.46087629412882,penalty='l2',solver='newton-cg',class_weight=weights,max_iter=1000)

# %%
#Instantiate the ML with the best model
#clf = LogisticRegression(**grid_result.best_params_)

# %%
#Fit and predict
timet = time.time() # Calculate time
clf.fit(X_train,y_train)
train_predictions = clf.predict(X_train)
test_predictions = clf.predict(X_test)
print(f'Time for the model training using optimized hyperparameter for OLS is: {time.time()-timet}')

#classification report
print('Classification Report Training set')
print('------------------------------------')
print('\n')
print(classification_report(y_train,train_predictions))
print('\n')

print('Classification Report Testing set')
print('------------------------------------')
print('\n')
print(classification_report(y_test,test_predictions))
# Out:
# Time for the model training using optimized hyperparameter for OLS is: 0.939650297164917
# Classification Report Training set
# ------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     23775
#            1       0.98      0.92      0.95      1794
#
#     accuracy                           0.99     25569
#    macro avg       0.99      0.96      0.97     25569
# weighted avg       0.99      0.99      0.99     25569
#
#
#
# Classification Report Testing set
# ------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      5945
#            1       0.72      0.60      0.66       448
#
#     accuracy                           0.96      6393
#    macro avg       0.85      0.79      0.82      6393
# weighted avg       0.95      0.96      0.95      6393

# %% [markdown]
# <a id='4-8'></a>
# ### _Fine tuned model with class weights proportional to the class imbalance_

# %%
#use the class weights to handle the imbalance in the labels
weights = {0:1.0,1:13}

if(hyperparameter == True):
    timet = time.time() # Calculate time
    clf = LogisticRegression(class_weight=weights,max_iter=1000)
    #Define the number of folds 
    folds = StratifiedKFold(n_splits=5,random_state= random_seed, shuffle=True)
    #Define search
    grid_search = RandomizedSearchCV(estimator=clf,param_distributions=space, n_iter=1000, scoring='recall',
                                n_jobs=-1, cv=folds, random_state=random_seed)
    #Fit grid search on the train data
    grid_result = grid_search.fit(X_train,y_train)

    #Determine the best model 
    grid_result.best_estimator_
    print(f'Time for the hyperparameter tuning account for weight imbalance for OLS is: {time.time()-timet}')

# %%
#Instantiate the best model
timet = time.time() # Calculate time

clf = LogisticRegression(C=0.16731783677034165,penalty='l2',solver='liblinear',class_weight=weights)

#clf = LogisticRegression(**grid_result.best_params_)

#fit and predict
clf.fit(X_train,y_train)
train_predictions = clf.predict(X_train)
test_predictions = clf.predict(X_test)

print(f'Time for the model training using optimized hyperparameters for OLS: {time.time()-timet}')

#classification report
print('Classification Report Training set')
print('------------------------------------')
print('\n')
print(classification_report(y_train,train_predictions))
print('\n')

print('Classification Report Testing set')
print('------------------------------------')
print('\n')
print(classification_report(y_test,test_predictions))
# Out:
# Time for the model training using optimized hyperparameters for OLS: 0.09169960021972656
# Classification Report Training set
# ------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97     23775
#            1       0.54      0.94      0.69      1794
#
#     accuracy                           0.94     25569
#    macro avg       0.77      0.94      0.83     25569
# weighted avg       0.96      0.94      0.95     25569
#
#
#
# Classification Report Testing set
# ------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.96      5945
#            1       0.47      0.77      0.59       448
#
#     accuracy                           0.92      6393
#    macro avg       0.73      0.85      0.77      6393
# weighted avg       0.95      0.92      0.93      6393

# %%
#plot_confusion_matrix(clf,X_test,y_test,cmap='summer') #Depreciated
#plt.title('Confusion Matrix for Test Dataset')
#plt.show()

# %%
# New way to play confusion matrix
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

cm_display = ConfusionMatrixDisplay(cm).plot()

# %%
prec, recall, _ = precision_recall_curve(y_test, y_pred,pos_label=clf.classes_[1])
fpr, tpr, _ = roc_curve(y_test, y_pred, pos_label=clf.classes_[1])

pr_display = PrecisionRecallDisplay(precision=prec, recall=recall)#.plot() #Enable plot if you want single plotting
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr)#.plot()
average_precision = average_precision_score(y_test, y_pred)

#Plot on a single panel
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))
plt.title(f'Precision-Recall curve: AP={average_precision:0.2f}')
roc_display.plot(ax=ax1)
pr_display.plot(ax=ax2)
plt.show()

# %%
def plot_pr_curve(recall, precision, average_precision):
    """
    https://scikit-learn.org/stable/auto_examples/model_selection/plot_precision_recall.html
    """
    from inspect import signature
    plt.figure()
    step_kwargs = ({'step': 'post'}
                   if 'step' in signature(plt.fill_between).parameters
                   else {})

    plt.step(recall, precision, color='b', alpha=0.2, where='post')
    plt.fill_between(recall, precision, alpha=0.2, color='b', **step_kwargs)

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.0])
    plt.xlim([0.0, 1.0])
    plt.title(f'2-class Precision-Recall curve: AP={average_precision:0.2f}')
    return plt.show()

# %%
## Calculate average precision and the PR curve
#average_precision = average_precision_score(y_test, y_pred)
#average_precision

# %%
# Plot the recall precision tradeoff
#plot_pr_curve(recall, prec, average_precision)

# %% [markdown]
# <a id='5'></a>
# ## _Summary of the OLS ML model_
#
# - Logistic Regression with default paramaters has a recall = 33%
# - Logistic Regression with class weights in proportion to the data imbalance has recall = 77%
# - Logistic Regression with optimized hyperparameters and balanced class weights has a recall = 60%
# - Logistic Regression with optimized hyperparameter and class weights in proportion to data imbalance has a recall = 85%

# %% [markdown]
# <a id="5"></a>
# ## <p style="background-color:#ffb037;font-family:newtimeroman;color:#2243b6;font-size:100%;text-align:center;border-radius:8px 10px;">MODEL BUILDING AND DEVELOPMENT BEYOND OLS: <br> Training/Testing and Cross-Validation  </p>

# %%
#instantiate the vectorizer 
vectorizer = TfidfVectorizer(max_features=5000)
#fit on the training data
X_sm = vectorizer.fit_transform(X)

# %%
# Handling imbalanced using SMOTE
correctimbalance = SMOTE()
X_sm,y_sm = correctimbalance.fit_resample(X_sm,y)

# %%
y_sm.value_counts()
# Out:
# 0    29720
# 1    29720
# Name: label, dtype: int64

# %%
#split the data 
timet = time.time() # Calculate time

X_train, X_test, y_train, y_test = train_test_split(X_sm,y_sm,test_size=test_size,
                                                    random_state=random_seed,stratify=y_sm)

MLA = [
    RandomForestClassifier(),
    LogisticRegression(solver='liblinear', max_iter=1000,class_weight='balanced'),
    LogisticRegressionCV(solver='liblinear', max_iter=1000,class_weight='balanced'), # Expensive
    RidgeClassifierCV(), # Expensive
    RidgeClassifier(),
    Perceptron(),
    BernoulliNB(),
    SGDClassifier(),
#    GaussianNB(), 
    MultinomialNB(),
    KNeighborsClassifier(),
#    svm.SVC(probability=True), # too expensive and accuracy metrics worse than just LinearSVC
#    svm.NuSVC(probability=True), # too expensive and accuracy metrics worse than just LinearSVC
    svm.LinearSVC(),
    DecisionTreeClassifier(),
    ExtraTreeClassifier(),
    XGBClassifier(eval_metric='auc',objective = 'binary:logistic'),
    AdaBoostClassifier(),
    ExtraTreesClassifier(),
    GradientBoostingClassifier()
]


col = []
algorithms = pd.DataFrame(columns = col)
idx = 0

#Train and score algorithms
#cv = RepeatedKFold(n_splits=10, n_repeats=5,random_state=110) #Apply cross-validation
cv = ShuffleSplit(n_splits = 10, test_size = test_size, random_state = random_seed)

for model in MLA:
    try:
        model.fit(X_train, y_train)
        cross_validation = cross_val_score(model, X_train, y_train, cv  = cv)
        pred = model.predict(X_test)
        acc = accuracy_score(y_test, pred) #Other way: model.score(X_test, y_test)
        f1 = f1_score(y_test, pred)#,pos_label='positive',average='micro')
        recall = recall_score(y_test, pred)#,pos_label='positive',average='micro')
        precision = precision_score(y_test, pred)#,pos_label='positive',average='micro')
        

        Alg = model.__class__.__name__

        algorithms.loc[idx, 'Algorithm'] = Alg
        algorithms.loc[idx, 'Accuracy'] = round(acc * 100, 2)
        algorithms.loc[idx, 'F1 Score'] = round(f1 * 100, 2)
        algorithms.loc[idx, 'Recall Score'] = round(recall * 100, 2)
        algorithms.loc[idx, 'Precision Score'] = round(precision * 100, 2)
        algorithms.loc[idx, 'CV Score'] = round(cross_validation.mean()* 100, 2)        
        algorithms.loc[idx, 'STD'] = round(std(cross_validation),3)
        CV_Score = pd.DataFrame({'CV-Scores for '+Alg: cross_validation})
#        print('CV-Score for',Alg)
#        print('--------------------------')
        display(CV_Score)
#        print('--------------------------')
        idx+=1
    except Exception as e:
        print(f"Exception occurred in {str(e)}")
        pass

print(f'Time for searching for the best ML model is: {time.time()-timet}')
# Out:
#    CV-Scores for RandomForestClassifier
# 0                              0.963095
# 1                              0.967511
# 2                              0.965093
# 3                              0.968878
# 4                              0.967406
# 5                              0.967722
# 6                              0.966144
# 7                              0.965303
# 8                              0.963411
# 9                              0.969614
#    CV-Scores for LogisticRegression
# 0                          0.932920
# 1                          0.937967
# 2                          0.924719
# 3                          0.930817
# 4                          0.933866
# 5                          0.929871
# 6                          0.931027
# 7                          0.934812
# 8                          0.932815
# 9                          0.928924
#    CV-Scores for LogisticRegressionCV
# 0                            0.959731
# 1                            0.961308
# ...

# %%
# Print the metrics
algorithms
# Out:
#                      Algorithm  Accuracy  F1 Score  Recall Score  \
# 0       RandomForestClassifier     97.03     97.07         98.54
# 1           LogisticRegression     94.04     94.22         97.04
# 2         LogisticRegressionCV     96.17     96.29         99.41
# 3            RidgeClassifierCV     94.69     94.87         98.22
# 4              RidgeClassifier     94.66     94.84         98.20
# 5                   Perceptron     94.36     94.38         94.63
# 6                  BernoulliNB     92.24     92.23         92.08
# 7                SGDClassifier     92.73     93.05         97.29
# 8                MultinomialNB     91.77     91.77         91.69
# 9         KNeighborsClassifier     64.79     73.88         99.58
# 10                   LinearSVC     95.53     95.67         98.67
# 11      DecisionTreeClassifier     96.17     96.22         97.36
# 12         ExtraTreeClassifier     95.27     95.38         97.70
# ...

# %%
#Plot them
g = sns.barplot("CV Score", "Algorithm", data = algorithms)
g.set_xlabel("CV score")
g = g.set_title("Algorithm Scores")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Plot confusion matrix
for model in MLA:
    try:
        predictions = model.predict(X_test)
#        cr = classification_report(y_test, predictions)
        cm       = confusion_matrix(y_test, predictions)
        # .sort_valuesPlot classification report
#        print("Classification Report for:\n----------------------\n", MLA)
#        print(cr)
        # plot confusion matrix 
        Alg = model.__class__.__name__
#        print("Confusion Matrix for:\n----------------------\n", Alg)
        plt.figure(figsize=(8,6))
        sentiment_classes = ['NonHate', 'Hate']
        sns.heatmap(cm, cmap=plt.cm.Blues, annot=True, fmt='d', 
                    xticklabels=sentiment_classes,
                    yticklabels=sentiment_classes)
        plt.title('Confusion matrix for '+Alg, fontsize=16)
        plt.xlabel('Actual label', fontsize=12)
        plt.ylabel('Predicted label', fontsize=12)
        plt.show()
    except Exception as e:
        print(f"Exception occurred in {str(e)}")
        pass

# %%
# Plot confusion matrix % Depreciated
#for model in MLA:
#    try:
#        #predictions = model.predict(X_test)
#        plot_confusion_matrix(model,X_test,y_test,cmap='summer')
##        cr = classification_report(y_test, predictions)
##        cm       = confusion_matrix(y_test, predictions)
#        # .sort_valuesPlot classification report
##        print("Classification Report for:\n----------------------\n", MLA)
##        print(cr)
#        # plot confusion matrix 
#        Alg = model.__class__.__name__
##        print("Confusion Matrix for:\n----------------------\n", Alg)
#        plt.title('Confusion matrix for '+Alg, fontsize=16)
#        plt.xlabel('Actual label', fontsize=12)
#        plt.ylabel('Predicted label', fontsize=12)
#        plt.show()
#    except Exception as e:
#        print(f"Exception occurred in {str(e)}")
#        pass

# %%
# New way to plot CM as the above is becoming depreciable
# Plot confusion matrix
for model in MLA:
    try:
        #predictions = model.predict(X_test)
        y_pred = model.predict(X_test)
        Alg = model.__class__.__name__
        cm = confusion_matrix(y_test, y_pred)
        cm_display = ConfusionMatrixDisplay(cm).plot()
#        print("Confusion Matrix for:\n----------------------\n", Alg)
        plt.title('Confusion matrix for '+Alg, fontsize=16)
        #plt.xlabel('Actual label', fontsize=12)
        #plt.ylabel('Predicted label', fontsize=12)
        plt.show()
    except Exception as e:
        print(f"Exception occurred in {str(e)}")
        pass

# %%
#Sort the 5 best models 
algorithms.sort_values(by = ['CV Score'], ascending = False, inplace = True)    
algorithms.head()
# Out:
#                  Algorithm  Accuracy  F1 Score  Recall Score  Precision Score  \
# 15    ExtraTreesClassifier     98.06     98.08         99.24            96.94
# 0   RandomForestClassifier     97.03     97.07         98.54            95.66
# 2     LogisticRegressionCV     96.17     96.29         99.41            93.36
# 11  DecisionTreeClassifier     96.17     96.22         97.36            95.10
# 10               LinearSVC     95.53     95.67         98.67            92.84
#
#     CV Score    STD
# 15     97.55  0.002
# 0      96.64  0.002
# 2      95.72  0.003
# 11     95.58  0.003
# 10     95.04  0.003

# %%
#Plot them
g = sns.barplot(x="CV Score", y="Algorithm", data = algorithms)
g.set_xlabel("CV score")
g = g.set_title("Algorithm Scores")

# %%
# convert the sentiments to categorical for plotting: 0 -> Neutral; 1 -> Positive; and 2 -> Negative
def convert_sentiment_string(sentiment):
    if  sentiment == 1:
        return "NotHate"
    elif sentiment == 0:
        return "Hate"
    else:
        return 'No such class exists'
l = [convert_sentiment_string(x) for x in list(Counter(y).keys())]
l
# Out:
# ['Hate', 'NotHate']

# %% [markdown]
# Hyper parameter tuning for the extratreeclassifier

# %%
timet = time.time() # Calculate time

bestmodel = ExtraTreesClassifier()

#ExtraTreesClassifier(n_estimators=100, n_jobs=4, min_samples_split=25,
#                            min_samples_leaf=35, max_features=150)


#class sklearn.ensemble.ExtraTreesClassifier(n_estimators=100, *, criterion='gini', 
#                                            max_depth=None, min_samples_split=2, min_samples_leaf=1, 
#                                            min_weight_fraction_leaf=0.0, max_features='auto', 
#                                            max_leaf_nodes=None, min_impurity_decrease=0.0, 
#                                            bootstrap=False, oob_score=False, n_jobs=None, 
#                                            random_state=None, 
#                                            verbose=0, warm_start=False, class_weight=None, 
#                                            ccp_alpha=0.0, max_samples=None)[source]

space = dict()
space['n_estimators'] = range(50,126,25)
space['max_features'] = range(50,401,50)
space['min_samples_leaf'] = range(20,50,5)
space['min_samples_split'] = range(10,36,5)
space['max_features'] = range(50,401,50)
space['criterion'] = ['gini', 'entropy']

#define the number of folds 
folds = StratifiedKFold(n_splits=5,random_state=random_seed,shuffle=True)
# define search
gsc = RandomizedSearchCV(
    estimator=bestmodel,
    param_distributions=space,
    scoring='recall',
    n_iter=500,
    n_jobs= 4,
    random_state=random_seed,
    return_train_score=True,
    cv=folds
)


grid_result = gsc.fit(X_train, y_train)

print(f'Time for hyperparameter tuning for the best ML model is: {time.time()-timet}')
# Out:
# Time for hyperparameter tuning for the best ML model is: 16801.277685403824

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
means_trainscores = grid_result.cv_results_['mean_train_score'] #mean_train_score
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

for test_mean, train_mean,stdev, param in zip(means,means_trainscores,stds,params):
  print("The test_mean is: %f and train_mean is: %f with std : %f and parameters: %r" % (test_mean,train_mean,stdev, param))
# Out:
# Best: 0.935818 using {'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': 50, 'criterion': 'entropy'}
# The test_mean is: 0.914115 and train_mean is: 0.919436 with std : 0.002783 and parameters: {'n_estimators': 75, 'min_samples_split': 30, 'min_samples_leaf': 25, 'max_features': 400, 'criterion': 'gini'}
# The test_mean is: 0.918195 and train_mean is: 0.922537 with std : 0.004097 and parameters: {'n_estimators': 50, 'min_samples_split': 35, 'min_samples_leaf': 30, 'max_features': 350, 'criterion': 'entropy'}
# The test_mean is: 0.915419 and train_mean is: 0.919404 with std : 0.004575 and parameters: {'n_estimators': 50, 'min_samples_split': 35, 'min_samples_leaf': 45, 'max_features': 300, 'criterion': 'gini'}
# The test_mean is: 0.857461 and train_mean is: 0.861036 with std : 0.047721 and parameters: {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 45, 'max_features': 50, 'criterion': 'gini'}
# ...

# %%
bestmodel = ExtraTreesClassifier(**grid_result.best_params_)
bestmodel.fit(X_train, y_train)

df_sub = pd.DataFrame({'y': test_predictions})
df_sub.to_csv('bestmodel.csv', index=False)

# %%
#Fit and predict
train_predictions = bestmodel.predict(X_train)
test_predictions = bestmodel.predict(X_test)

#classification report
print('Classification Report Training set')
print('------------------------------------')
print('\n')
print(classification_report(y_train,train_predictions))
print('\n')

print('Classification Report Testing set')
print('------------------------------------')
print('\n')
print(classification_report(y_test,test_predictions))
# Out:
# Classification Report Training set
# ------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90     23776
#            1       0.88      0.94      0.91     23776
#
#     accuracy                           0.91     47552
#    macro avg       0.91      0.91      0.90     47552
# weighted avg       0.91      0.91      0.90     47552
#
#
#
# Classification Report Testing set
# ------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90      5944
#            1       0.88      0.93      0.91      5944
#
#     accuracy                           0.90     11888
#    macro avg       0.90      0.90      0.90     11888
# weighted avg       0.90      0.90      0.90     11888

# %%
# Plot the confusion matrix
y_pred = test_predictions
cm = confusion_matrix(y_test, y_pred)

cm_display = ConfusionMatrixDisplay(cm).plot()

# %%
# Plot the roc and precision-recall plot for the test data
prec, recall, _ = precision_recall_curve(y_test, y_pred,pos_label=clf.classes_[1])
fpr, tpr, _ = roc_curve(y_test, y_pred, pos_label=clf.classes_[1])

pr_display = PrecisionRecallDisplay(precision=prec, recall=recall)#.plot() #Enable plot if you want single plotting
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr)#.plot()
average_precision = average_precision_score(y_test, y_pred)

#Plot on a single panel
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))
plt.title(f'Precision-Recall curve: AP={average_precision:0.2f}')
roc_display.plot(ax=ax1)
pr_display.plot(ax=ax2)
plt.show()

# %% [markdown]
# <a id='5'></a>
# ## _Summary of the Best ML model_
# ##### _Best ML Model is the ExtraTreesClassifier_
#
# ##### Note, imbalance is take care of with Smote
#
# - Using default paramaters the average recall = 99.24%
# - Using the optimized hyperparameter the recall = 93.00%
# - A combination of smothe and hyperparameter training provided a better treatment of the imbalance with overall better statistics of the dataset

# %%
print(f'Total time for the case study is: {time.time()-timetotal}')
# Out:
# Total time for the case study is: 20640.676064014435

# %% [markdown]
# <a id="5"></a>
# ## <p style="background-color:#ffb037;font-family:newtimeroman;color:#2243b6;font-size:200%;text-align:center;border-radius:8px 10px;">END OF CASE STUDY </p>
